# %%
# %pip install matplotlib ipywidgets

# %%
from src.core import HexagoneMagique

hex = HexagoneMagique(show_widget=True)

hex.mettre(0, 10)
hex.mettre(1, 15)
hex.mettre(1, 12)
hex.mettre(8,10)

# %%
spiral = [
    9,
    10,
    14,
    18,
    17,
    16,
    15,
    11,
    6,
    2,
    1,
    0,
    3,
    7,
    12,
    13,
    8,
    4,
    5
]
hexagon.fixer_parcours(spiral)

print("Spiral ordering applied:")
print(hexagon.tracer_parcours())

import numpy as np
bg = np.ones((320, 320, 3), dtype=float)
for i in range(bg.shape[0]):
    t = i / (bg.shape[0] - 1)
    bg[i, :, 0] = 0.95 - 0.15 * t
    bg[i, :, 1] = 0.92 - 0.04 * t
    bg[i, :, 2] = 1.00 - 0.12 * t

hexagon.set_background_image(bg)
hexagon.show_widget()

# Programmatic updates refresh the display automatically.
hexagon.mettre(0, 5)
hexagon.mettre(1, 6)
